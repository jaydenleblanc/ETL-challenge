# %%
#Dependencies
import pandas as pd
# SQL Alchemy
from sqlalchemy import create_engine

# %%
# Create Engine for Pitchfork
pitchfork_database_path = "./Resources/pitchfork.sqlite"
engine = create_engine(f"sqlite:///{pitchfork_database_path}")
conn = engine.connect()

# %%
engine.table_names()
# Out:
# ['artists', 'content', 'genres', 'labels', 'reviews', 'top10', 'years']

# %%
pitchfork_data = pd.read_sql("SELECT * FROM reviews", conn)
pitchfork_data.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3      jenn pelly  associate reviews editor  2017-01-06            4        6
# 4    kevin lozano        tracks coordinator  2017-01-06            4        6
#
#    pub_month  pub_year
# 0          1      2017
# 1          1      2017
# 2          1      2017
# 3          1      2017
# 4          1      2017

# %%
#Store Spotify CSV into Dataframe
spotify_csv = "Resources/spotify_top10s.csv"
spotify_data_df = pd.read_csv(spotify_csv, encoding = "ISO-8859-1")
spotify_data_df.head()

#Create new data with select columns:
new_spotify_data_df = spotify_data_df[['title','artist','year']]
new_spotify_data_df
# Out:
#                                                  title            artist  year
# 0                                     Hey, Soul Sister             Train  2010
# 1                                 Love The Way You Lie            Eminem  2010
# 2                                              TiK ToK             Kesha  2010
# 3                                          Bad Romance         Lady Gaga  2010
# 4                                 Just the Way You Are        Bruno Mars  2010
# ..                                                 ...               ...   ...
# 598                Find U Again (feat. Camila Cabello)       Mark Ronson  2019
# 599      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran  2019
# 600  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled  2019
# 601    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson  2019
# 602                                   Kills You Slowly  The Chainsmokers  2019
#
# [603 rows x 3 columns]

# %%
#spotify_data_df.head()

# %%
#Use pandas to load csv converted DataFrame into database
new_spotify_data_df.to_sql(name='top10', con=engine,if_exists='append',index=False)

# %%
#Confirm data has been added by querying the table
pd.read_sql_query('select * from top10', con=engine).head()
# Out:
#                   title      artist  year
# 0      Hey, Soul Sister       Train  2010
# 1  Love The Way You Lie      Eminem  2010
# 2               TiK ToK       Kesha  2010
# 3           Bad Romance   Lady Gaga  2010
# 4  Just the Way You Are  Bruno Mars  2010

# %%
pitchfork_data = pd.read_sql("SELECT * FROM years", conn)

#columns in table
print(list(pitchfork_data.columns))
# Out:
# ['reviewid', 'year']

# %%
#Investigating merge between both dataframes
initial_reviews = pd.read_sql("SELECT * FROM reviews", conn)
initial_reviews
reviews = initial_reviews[['reviewid','artist','score','author','pub_year']]
reviews
# Out:
#        reviewid            artist  score           author  pub_year
# 0         22703    massive attack    9.3      nate patrin      2017
# 1         22721          krallice    7.9         zoe camp      2017
# 2         22659      uranium club    7.3   david glickman      2017
# 3         22661  kleenex, liliput    9.0       jenn pelly      2017
# 4         22725              taso    8.1     kevin lozano      2017
# ...         ...               ...    ...              ...       ...
# 18388      1535           coldcut    8.9  james p. wisdom      1999
# 18389      1341           cassius    4.8  james p. wisdom      1999
# 18390      5376          mojave 3    6.3   jason josephes      1999
# 18391      2413     don caballero    7.2  james p. wisdom      1999
# 18392      3723    neil hamburger    6.5   jason josephes      1999
#
# [18393 rows x 5 columns]

# %%
content = pd.read_sql("SELECT * FROM content", conn)
content
# Out:
#        reviewid                                            content
# 0         22703  “Trip-hop” eventually became a ’90s punchline,...
# 1         22721  Eight years, five albums, and two EPs in, the ...
# 2         22659  Minneapolis’ Uranium Club seem to revel in bei...
# 3         22661  Kleenex began with a crash. It transpired one ...
# 4         22725  It is impossible to consider a given release b...
# ...         ...                                                ...
# 18388      1535  The marketing guys of yer average modern megac...
# 18389      1341  Well, it's been two weeks now, and I guess it'...
# 18390      5376  Out of Tune is a Steve Martin album.  Yes, I'l...
# 18391      2413  Well, kids, I just went back and re-read my re...
# 18392      3723  Neil Hamburger's third comedy release is a des...
#
# [18393 rows x 2 columns]

# %%
content['reviewid'].nunique()
# Out:
# 18389

# %%
#merge dataframes on reviewid column
content_reviews = reviews.merge(content, how='inner',on='reviewid')
content_reviews
# Out:
#        reviewid            artist  score           author  pub_year  \
# 0         22703    massive attack    9.3      nate patrin      2017
# 1         22721          krallice    7.9         zoe camp      2017
# 2         22659      uranium club    7.3   david glickman      2017
# 3         22661  kleenex, liliput    9.0       jenn pelly      2017
# 4         22725              taso    8.1     kevin lozano      2017
# ...         ...               ...    ...              ...       ...
# 18396      1535           coldcut    8.9  james p. wisdom      1999
# 18397      1341           cassius    4.8  james p. wisdom      1999
# 18398      5376          mojave 3    6.3   jason josephes      1999
# 18399      2413     don caballero    7.2  james p. wisdom      1999
# 18400      3723    neil hamburger    6.5   jason josephes      1999
#
#                                                  content
# 0      “Trip-hop” eventually became a ’90s punchline,...
# 1      Eight years, five albums, and two EPs in, the ...
# 2      Minneapolis’ Uranium Club seem to revel in bei...
# 3      Kleenex began with a crash. It transpired one ...
# 4      It is impossible to consider a given release b...
# ...                                                  ...
# 18396  The marketing guys of yer average modern megac...
# 18397  Well, it's been two weeks now, and I guess it'...
# 18398  Out of Tune is a Steve Martin album.  Yes, I'l...
# 18399  Well, kids, I just went back and re-read my re...
# 18400  Neil Hamburger's third comedy release is a des...
#
# [18401 rows x 6 columns]

# %%
#Checking for duplicates in the Pitchfork reviews
duplicate_reviews = content_reviews[content_reviews.duplicated()]
duplicate_reviews
# Out:
#        reviewid               artist  score          author  pub_year  \
# 12117      9417  easy star all-stars    7.0     joe tangari      2006
# 12118      9417  easy star all-stars    7.0     joe tangari      2006
# 12119      9417  easy star all-stars    7.0     joe tangari      2006
# 12121      9505      various artists    8.2      tim finney      2006
# 12122      9505      various artists    8.2      tim finney      2006
# 12123      9505      various artists    8.2      tim finney      2006
# 12125      9499   the blood brothers    6.2     jason crock      2006
# 12126      9499   the blood brothers    6.2     jason crock      2006
# 12127      9499   the blood brothers    6.2     jason crock      2006
# 12129      9460              xasthur    7.8  brandon stosuy      2006
# 12130      9460              xasthur    7.8  brandon stosuy      2006
# 12131      9460              xasthur    7.8  brandon stosuy      2006
#
#                                                  content
# 12117  \r\n    A song-for-song reggae cover of Radioh...
# 12118  \r\n    A song-for-song reggae cover of Radioh...
# 12119  \r\n    A song-for-song reggae cover of Radioh...
# 12121  \nOn the one hand it is a largely superfluous ...
# 12122  \nOn the one hand it is a largely superfluous ...
# 12123  \nOn the one hand it is a largely superfluous ...
# 12125  When we last left our heroes, the Blood Brothe...
# 12126  When we last left our heroes, the Blood Brothe...
# 12127  When we last left our heroes, the Blood Brothe...
# 12129  Strange things are a foot in the bowels of hel...
# 12130  Strange things are a foot in the bowels of hel...
# 12131  Strange things are a foot in the bowels of hel...

# %%
#Drop columns with identical values in all columns
content_reviews = content_reviews.drop_duplicates(subset = ["reviewid", "artist", "score", "author", "content"])

# %%
#checking that all the duplicate reviews were dropped - if so, then this command should not return us any rows
duplicate_reviews_2 = content_reviews[content_reviews.duplicated()]
duplicate_reviews_2
# Out:
# Empty DataFrame
# Columns: [reviewid, artist, score, author, pub_year, content]
# Index: []

# %%
top10 = pd.read_sql("SELECT * FROM top10", conn)
top10
# Out:
#                                                   title            artist  \
# 0                                      Hey, Soul Sister             Train
# 1                                  Love The Way You Lie            Eminem
# 2                                               TiK ToK             Kesha
# 3                                           Bad Romance         Lady Gaga
# 4                                  Just the Way You Are        Bruno Mars
# ...                                                 ...               ...
# 3613                Find U Again (feat. Camila Cabello)       Mark Ronson
# 3614      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 3615  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 3616    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 3617                                   Kills You Slowly  The Chainsmokers
#
#       year
# 0     2010
# 1     2010
# 2     2010
# 3     2010
# 4     2010
# ...    ...
# 3613  2019
# 3614  2019
# 3615  2019
# 3616  2019
# 3617  2019
#
# [3618 rows x 3 columns]

# %%
#checking to see if there are any duplicate Spotify chart entries
top10_dupes = top10[top10.duplicated()]
top10_dupes
# Out:
#                                                   title            artist  \
# 322                                               Sugar          Maroon 5
# 603                                    Hey, Soul Sister             Train
# 604                                Love The Way You Lie            Eminem
# 605                                             TiK ToK             Kesha
# 606                                         Bad Romance         Lady Gaga
# ...                                                 ...               ...
# 3613                Find U Again (feat. Camila Cabello)       Mark Ronson
# 3614      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 3615  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 3616    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 3617                                   Kills You Slowly  The Chainsmokers
#
#       year
# 322   2015
# 603   2010
# 604   2010
# 605   2010
# 606   2010
# ...    ...
# 3613  2019
# 3614  2019
# 3615  2019
# 3616  2019
# 3617  2019
#
# [3016 rows x 3 columns]

# %%
#it's hard to get a sense of the dupes with the command above, since they're not sorted. 
#Let's sort them by title so that we can visualize the duplicate entries
top10_dupes.sort_values(by=['title'])
# Out:
#                      title         artist  year
# 802             #Beautiful   Mariah Carey  2013
# 1405            #Beautiful   Mariah Carey  2013
# 2611            #Beautiful   Mariah Carey  2013
# 3214            #Beautiful   Mariah Carey  2013
# 2008            #Beautiful   Mariah Carey  2013
# ...                    ...            ...   ...
# 3528  no tears left to cry  Ariana Grande  2018
# 1719  no tears left to cry  Ariana Grande  2018
# 1116  no tears left to cry  Ariana Grande  2018
# 2322  no tears left to cry  Ariana Grande  2018
# 2925  no tears left to cry  Ariana Grande  2018
#
# [3016 rows x 3 columns]

# %%
#Drop columns with identical values in all columns, but keep the first entry
top10 = top10.drop_duplicates(subset=['title', 'artist', 'year'], keep='first')

# %%
#now if we sort the top10 by title, we shouldn't be seeing any dupes
top10.sort_values(by=['title'])
# Out:
#                                   title            artist  year
# 199                          #Beautiful      Mariah Carey  2013
# 240                             #SELFIE  The Chainsmokers  2014
# 173                          #thatPOWER         will.i.am  2013
# 569  ...Ready For It? - BloodPop® Remix      Taylor Swift  2018
# 87                                  1+1           Beyoncé  2011
# ..                                  ...               ...   ...
# 490                         Younger Now       Miley Cyrus  2017
# 19                 Your Love Is My Drug             Kesha  2010
# 538                Youth (feat. Khalid)      Shawn Mendes  2018
# 233                               human   Christina Perri  2014
# 513                no tears left to cry     Ariana Grande  2018
#
# [602 rows x 3 columns]

# %%
#we know that eminem is in our spotify chart data. Let's make sure that there are pitchfork reviews on him too. 
#this way, we know that we have data to join
content_reviews[content_reviews["artist"].isin(["eminem"])]
# Out:
#        reviewid  artist  score            author  pub_year  \
# 3704      18733  eminem    4.7     craig jenkins      2013
# 7704      14380  eminem    2.8     jayson greene      2010
# 8990      13034  eminem    4.8         ian cohen      2009
# 13124      2773  eminem    6.9    sean fennessey      2005
# 14384      2772  eminem    6.5  scott plagenhoef      2004
# 16951      2771  eminem    9.1          ethan p.      2002
#
#                                                  content
# 3704   The more the triumphs of Eminem’s world beatin...
# 7704   Watching Eminem attempt to re-situate himself ...
# 8990   You might think calling Eminem "divisive"  in ...
# 13124  Frankly, I don't want to hear these songs anym...
# 14384  In 2000, Eminem was frequently vilified as a h...
# 16951  ryan loves it and he likes mmlp too so he's al...

# %%
#making the artist column in the Pitchfork Reviews a Title format, so that we can join it to the Spotify data
content_reviews['artist'] = content_reviews['artist'].str.title()
# Out:
# C:\Users\jayde\anaconda3new\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#confirming that the artist names are now in title format
content_reviews
# Out:
#        reviewid            artist  score           author  pub_year  \
# 0         22703    Massive Attack    9.3      nate patrin      2017
# 1         22721          Krallice    7.9         zoe camp      2017
# 2         22659      Uranium Club    7.3   david glickman      2017
# 3         22661  Kleenex, Liliput    9.0       jenn pelly      2017
# 4         22725              Taso    8.1     kevin lozano      2017
# ...         ...               ...    ...              ...       ...
# 18396      1535           Coldcut    8.9  james p. wisdom      1999
# 18397      1341           Cassius    4.8  james p. wisdom      1999
# 18398      5376          Mojave 3    6.3   jason josephes      1999
# 18399      2413     Don Caballero    7.2  james p. wisdom      1999
# 18400      3723    Neil Hamburger    6.5   jason josephes      1999
#
#                                                  content
# 0      “Trip-hop” eventually became a ’90s punchline,...
# 1      Eight years, five albums, and two EPs in, the ...
# 2      Minneapolis’ Uranium Club seem to revel in bei...
# 3      Kleenex began with a crash. It transpired one ...
# 4      It is impossible to consider a given release b...
# ...                                                  ...
# 18396  The marketing guys of yer average modern megac...
# 18397  Well, it's been two weeks now, and I guess it'...
# 18398  Out of Tune is a Steve Martin album.  Yes, I'l...
# 18399  Well, kids, I just went back and re-read my re...
# 18400  Neil Hamburger's third comedy release is a des...
#
# [18389 rows x 6 columns]

# %%
#Merge top10 with content_reviews
top10_content_reviews = content_reviews.merge(top10, how='inner',on='artist')
top10_content_reviews
# Out:
#      reviewid         artist  score               author  pub_year  \
# 0       22645    John Legend    7.0      marcus j. moore      2016
# 1       22645    John Legend    7.0      marcus j. moore      2016
# 2       22634     Bruno Mars    6.2  katherine st. asaph      2016
# 3       22634     Bruno Mars    6.2  katherine st. asaph      2016
# 4       22634     Bruno Mars    6.2  katherine st. asaph      2016
# ..        ...            ...    ...                  ...       ...
# 609      2756  Missy Elliott    7.2        sam chennault      2002
# 610      2756  Missy Elliott    7.2        sam chennault      2002
# 611      2757  Missy Elliott    8.2           dan kilian      2001
# 612      2757  Missy Elliott    8.2           dan kilian      2001
# 613      9136  Nelly Furtado    6.4       sean fennessey      2006
#
#                                                content                  title  \
# 0    John Legend doesn’t waste time getting to the ...              All of Me
# 1    John Legend doesn’t waste time getting to the ...                  Start
# 2    It’s good to remember the improbable things in...   Just the Way You Are
# 3    It’s good to remember the improbable things in...              Marry You
# 4    It’s good to remember the improbable things in...   Just the Way You Are
# ..                                                 ...                    ...
# 609  Aside from Eminem, Missy "Misdemeanor" Elliott...  WTF (Where They From)
# 610  Aside from Eminem, Missy "Misdemeanor" Elliott...              Pep Rally
# 611  A lot of albums kick off with the killer track...  WTF (Where They From)
# 612  A lot of albums kick off with the killer track...              Pep Rally
# 613  \nLoose is the best and worst\r\n    pop album...       Behind Your Back
#
#      year
# 0    2014
# 1    2016
# 2    2010
# 3    2010
# 4    2011
# ..    ...
# 609  2016
# 610  2016
# 611  2016
# 612  2016
# 613  2016
#
# [614 rows x 8 columns]

# %%
#Checking for duplicates - there should be none
duplicate_entries_3 = top10_content_reviews[top10_content_reviews.duplicated()]
duplicate_entries_3
# Out:
# Empty DataFrame
# Columns: [reviewid, artist, score, author, pub_year, content, title, year]
# Index: []

# %%
top10_content_reviews[top10_content_reviews["artist"].isin(["Eminem"])]
# Out:
#      reviewid  artist  score            author  pub_year  \
# 532     18733  Eminem    4.7     craig jenkins      2013
# 533     18733  Eminem    4.7     craig jenkins      2013
# 534     14380  Eminem    2.8     jayson greene      2010
# 535     14380  Eminem    2.8     jayson greene      2010
# 536     13034  Eminem    4.8         ian cohen      2009
# 537     13034  Eminem    4.8         ian cohen      2009
# 538      2773  Eminem    6.9    sean fennessey      2005
# 539      2773  Eminem    6.9    sean fennessey      2005
# 540      2772  Eminem    6.5  scott plagenhoef      2004
# 541      2772  Eminem    6.5  scott plagenhoef      2004
# 542      2771  Eminem    9.1          ethan p.      2002
# 543      2771  Eminem    9.1          ethan p.      2002
#
#                                                content  \
# 532  The more the triumphs of Eminem’s world beatin...
# 533  The more the triumphs of Eminem’s world beatin...
# 534  Watching Eminem attempt to re-situate himself ...
# 535  Watching Eminem attempt to re-situate himself ...
# 536  You might think calling Eminem "divisive"  in ...
# 537  You might think calling Eminem "divisive"  in ...
# 538  Frankly, I don't want to hear these songs anym...
# 539  Frankly, I don't want to hear these songs anym...
# 540  In 2000, Eminem was frequently vilified as a h...
# 541  In 2000, Eminem was frequently vilified as a h...
# 542  ryan loves it and he likes mmlp too so he's al...
# 543  ryan loves it and he likes mmlp too so he's al...
#
#                              title  year
# 532           Love The Way You Lie  2010
# 533  Walk On Water (feat. Beyoncé)  2018
# 534           Love The Way You Lie  2010
# 535  Walk On Water (feat. Beyoncé)  2018
# 536           Love The Way You Lie  2010
# 537  Walk On Water (feat. Beyoncé)  2018
# 538           Love The Way You Lie  2010
# 539  Walk On Water (feat. Beyoncé)  2018
# 540           Love The Way You Lie  2010
# 541  Walk On Water (feat. Beyoncé)  2018
# 542           Love The Way You Lie  2010
# 543  Walk On Water (feat. Beyoncé)  2018
